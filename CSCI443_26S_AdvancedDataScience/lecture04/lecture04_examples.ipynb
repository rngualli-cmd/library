# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
#print(spark.sparkContext.appName).  # Can't so this.  Generates JVM_ATTRIBUTE_NOT_SUPPORTED
#print(spark.conf.get("spark.app.name")). # also can't do this community edition
spark2 = SparkSession.builder.getOrCreate()
print(spark is spark2)

# %%
dir_path = "/Volumes/workspace/default/files"
display(dbutils.fs.ls(dir_path))

# %%
import os
file_path = os.path.join(dir_path, "train.csv")
spark_df = spark.read.option("header", "true").csv(file_path)

spark_df.printSchema(10)

# %%
display(spark_df)

# %%
some_rows = spark_df.head(10)
type(some_rows)

# %%
display(some_rows)  # pretty printing
